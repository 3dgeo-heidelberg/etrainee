# %% [markdown]
# <details>
#    <summary>Metadata</summary>
#     title: "E-TRAINEE Time series analysis of 3D point clouds"
#     description: "This is the fourth theme within the 3D/4D Geographic Point Cloud Time Series Analysis module."
#     dateCreated: 2022-01-12
#     authors: Katharina Anders and Bernhard Höfle
#     contributors:
#     estimatedTime: 1.5 hours
# </details>

# %% [markdown]
# # Theme Y
#
# Introduction with background and motivation
#
# ## Objectives
#
# ...
#
#
# ## Methods
#
#
# * code snippets:

# %% [markdown]
# Links to sections etc. must be inserted with html syntax:
#
# <a href="#test-header">my text</a>
#
# <a id="test-header"></a>
# ## test header

# %%
#comment

# importing various package 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

# reading time series
dummy_data = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/daily-min-temperatures.csv'
s = pd.read_csv(dummy_data, header=0, index_col=0, parse_dates=True, squeeze=True)

# Creating Autocorrelation plot 
x = pd.plotting.autocorrelation_plot(s) 

# ploting the Curve 
x.plot() 

# Display 
plt.show()

# %% [markdown]
# We continue with more theory and explanation.
